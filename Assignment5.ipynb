# %% [markdown]
# ## Assignment 5 :- Importing,Creating Modules and Pakcages

# %% [markdown]
# ### Task 1:- Creating a maths module
# #### The module contains addition and substraction of two numbers and squaring of a number

# %%
import math_utils
print(f"The addition of the number 5 and 3 is: {math_utils.add(5,3)}")
print(f"The substraction of the number 5 and 3 is: {math_utils.substract(5,3)}")
print(f"The square of the number 5 is: {math_utils.square(5)}")
# Out:
# The addition of the number 5 and 3 is: 8
# The substraction of the number 5 and 3 is: 2
# The square of the number 5 is: 25

# %%
from math_utils import add, substract, square
print(f"The addition of the number 5 and 3 is: {add(5,3)}")
print(f"The substraction of the number 5 and 3 is: {substract(5,3)}")
print(f"The square of the number 5 is: {square(5)}")
# Out:
# The addition of the number 5 and 3 is: 8
# The substraction of the number 5 and 3 is: 2
# The square of the number 5 is: 25

# %% [markdown]
# ### Task 2:- Create string_utils.py
# #### Using a module to capitalize each word , reversing a text or return the words in a text.

# %%
from string_utils import *
text =input("Enter a string :")
print("After capitalizing each word the string is:",capitalized_words(text))
print("After reversing the string is:",reverse_string(text))
print("The total words in the string is:",{word_count(text)})
# Out:
# After capitalizing each word the string is: Quick Brown Fox Jumps Over The Lazy Dog.
# After reversing the string is: .god yzal eht revo spmuj xof nworb kciuQ
# The total words in the string is: {8}

# %% [markdown]
# ### Task 3:- Creating a shop package
# #### Creating a package that contain two module.
# #### One module named discount.py that apply discount based on percent and other apply flat 50 amount from the price
# #### The billing.py module contain function to tell total price and another function to apply 5% tax.

# %% [markdown]
# ### Task 4:- Import shop_package into the Jupyter Notebook
# #### In this task, we will do the various ways of importing the required function from the package to resolve our issue.

# %%
import shop_package.discount as disc
## Price of the item ans disocunt
original_price=1000
discount_percent=10
print(f"The discounted price is :{int(disc.apply_discount(original_price,discount_percent))}")

## Applying flat discount on above original price
print(f"The flat rate of this item would be {disc.flat_discount(original_price)}")
# Out:
# The discounted price is :900
# The flat rate of this item would be 950

# %%
## Calculating the total and applying tax on it as well

from shop_package import calculate_total,apply_tax
prices=[500,600,750,400,300,1000]
total_bill=calculate_total(prices)
print(f"The total bill is: {total_bill}")
print(f'The total bill including tax is : {apply_tax(total_bill)}')
# Out:
# The total bill is: 3550
# The total bill including tax is : 3727.5
